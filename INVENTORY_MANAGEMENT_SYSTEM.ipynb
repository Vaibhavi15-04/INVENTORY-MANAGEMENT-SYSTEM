# %% [markdown]
# <a href="https://colab.research.google.com/github/Vaibhavi15-04/INVENTORY-MANAGEMENT-SYSTEM/blob/main/INVENTORY_MANAGEMENT_SYSTEM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#-------------------------------------------------------------------------------------------------------------------
#----------------------CREATING JSON FILES FOR MY PRODUCTS ACCORDINGLY TO THEIR CATEGORY----------------------------
#-------------------------------------------------------------------------------------------------------------------

frozen_food_snacks={ 100501:{'name':'potato nuggets','price':65,'mfg_date':'26-04-21','exp_date':'26-04-23','qty':158,'brand':'mccain'},
                    100502:{'name':'cheese balls','price':85,'mfg_date':'11-04-21','exp_date':'26-12-21','qty':188,'brand':'mccain'},
                    100503:{'name':'pizza','price':120,'mfg_date':'26-08-21','exp_date':'26-12-23','qty':175,'brand':'amul'},
                    100504:{'name':'mozzarela bites','price':96,'mfg_date':'16-07-21','exp_date':'26-04-22','qty':140,'brand':'milkymist'},
                    100505:{'name':'french fries','price':90,'mfg_date':'26-05-21','exp_date':'26-05-23','qty':120,'brand':'amul'},
                    100506:{'name':'nachos','price':45,'mfg_date':'06-08-21','exp_date':'06-08-23','qty':150,'brand':'chevon'},
                    100507:{'name':'Pasta chips','price':65,'mfg_date':'06-04-21','exp_date':'11-04-22','qty':150,'brand':'capricon'},
                    100508:{'name':'potato chips','price':65,'mfg_date':'02-04-21','exp_date':'12-05-21','qty':170,'brand':'lays'},
                    100509:{'name':'mac and cheese','price':65,'mfg_date':'24-04-21','exp_date':'21-05-21','qty':160,'brand':'nestle'},
                    100510:{'name':'hakka noddles','price':65,'mfg_date':'15-04-21','exp_date':'02-04-22','qty':130,'brand':'chings'},
    
}

oils={100601:{'name':'rice oil','price':859,'mfg_date':'25-05-21','exp_date':'25-05-24','qty':165,'brand':'saffola'},
      100602:{'name':'olive oil','price':755,'mfg_date':'01-05-21','exp_date':'01-05-24','qty':100,'brand':'fortune'},
      100603:{'name':'peanut oil(filtered)','price':922,'mfg_date':'01-07-21','exp_date':'01-05-24','qty':165,'brand':'saffola'},
      100604:{'name':'peanut oil(refined)','price':752,'mfg_date':'01-06-21','exp_date':'01-06-24','qty':160,'brand':'sundrop'},
      100605:{'name':'cotton oil','price':999,'mfg_date':'01-04-21','exp_date':'15-04-24','qty':150,'brand':'saffola'},
      100606:{'name':'avacado oil','price':832,'mfg_date':'15-06-21','exp_date':'02-06-24','qty':140,'brand':'dhara'},
      100607:{'name':'mustrad oil','price':856,'mfg_date':'01-05-21','exp_date':'25-05-24','qty':199,'brand':'dhara'},
      100608:{'name':'soyabean oil','price':789,'mfg_date':'25-06-21','exp_date':'25-06-24','qty':186,'brand':'dhara'},
      100609:{'name':'coconut oil','price':856,'mfg_date':'25-07-21','exp_date':'25-07-24','qty':145,'brand':'sundrop'},
      100610:{'name':'extra vigin olive oil','price':985,'mfg_date':'01-03-21','exp_date':'01-05-24','qty':170,'brand':'vincetin'},
      100611:{'name':'walnut oil','price':1200,'mfg_date':'11-05-21','exp_date':'01-05-24','qty':155,'brand':'cargill'},
      100612:{'name':'seasme oil','price':1000,'mfg_date':'21-05-21','exp_date':'01-05-24','qty':155,'brand':'kaneka'},
      100613:{'name':'flaxseed oil','price':986,'mfg_date':'15-05-21','exp_date':'05-05-24','qty':145,'brand':'vincetin'}

    
}

soaps_shampoo={100801:{'name':'shampoo(loreal)','price':84,'mfg_date':'12-07-21','exp_date':'12-07-23','qty':155,'brand':'loreal'},
           100802:{'name':'shampoo(dove)','price':104,'mfg_date':'01-07-21','exp_date':'01-07-23','qty':185,'brand':'dove'},
           100803:{'name':'shampoo(treseme)','price':114,'mfg_date':'01-05-21','exp_date':'01-10-23','qty':195,'brand':'treseme'},
           100804:{'name':'shampoo(clinic plus)','price':94,'mfg_date':'10-04-21','exp_date':'01-11-23','qty':150,'brand':'clinic plus'},
           100805:{'name':'soap(dove)','price':130,'mfg_date':'10-07-21','exp_date':'01-12-23','qty':164,'brand':'dove'},
           100806:{'name':'soap(pears)','price':130,'mfg_date':'12-05-21','exp_date':'01-01-23','qty':188,'brand':'pears'},
           100807:{'name':'soap(lux)','price':90,'mfg_date':'20-06-21','exp_date':'01-02-23','qty':196,'brand':'lux'},
           100808:{'name':'conditioner(dove)','price':144,'mfg_date':'01-07-21','exp_date':'01-03-23','qty':145,'brand':'dove'},
           100809:{'name':'conditioner(loreal)','price':104,'mfg_date':'01-01-21','exp_date':'01-04-23','qty':175,'brand':'loreal'},
           100810:{'name':'conditioner(treseme)','price':154,'mfg_date':'11-07-21','exp_date':'01-05-23','qty':150,'brand':'treseme'}
    
}

dairy_products={100401:{'name':'mozrellacheese','price':85,'mfg_date':'12-08-21','exp_date':'12-12-21','qty':145,'brand':'amul'},
                100402:{'name':'butter','price':95,'mfg_date':'01-08-21','exp_date':'10-12-21','qty':165,'brand':'amul'},
                100403:{'name':'almond milk','price':105,'mfg_date':'01-05-21','exp_date':'01-12-21','qty':185,'brand':'amul'},
                100404:{'name':'cottage cheese','price':75,'mfg_date':'22-07-21','exp_date':'15-12-21','qty':140,'brand':'amul'},
                100405:{'name':'ice cream','price':145,'mfg_date':'10-08-21','exp_date':'14-12-21','qty':195,'brand':'amul'},
                100406:{'name':'yoghurt','price':75,'mfg_date':'01-09-21','exp_date':'10-12-21','qty':105,'brand':'amul'},
                100407:{'name':'strawberry milk','price':110,'mfg_date':'12-05-21','exp_date':'10-10-21','qty':185,'brand':'amul'},
                100408:{'name':'condensed milk','price':125,'mfg_date':'01-07-21','exp_date':'10-11-21','qty':174,'brand':'amul'},
                100409:{'name':'whipped cream','price':120,'mfg_date':'02-07-21','exp_date':'01-09-21','qty':146,'brand':'amul'}
    
}


#------------------------------------------------------------------------------------------------------------------------

import json 
js1=json.dumps(frozen_food_snacks)

fd=open("frozen_food_snacks.json",'w')
fd.write(js1)

fd.close()

fd=open("frozen_food_snacks.json",'r')
r1=fd.read()
fd.close()
frozen_food_snacks=json.loads(r1)

#--------------------------------------------------------------------------------

import json 
js2=json.dumps(oils)

fd=open("oils.json",'w')
fd.write(js2)

fd.close()



fd=open("oils.json",'r')
r2=fd.read()
fd.close()
oils=json.loads(r2)

#-------------------------------------------------------------------------------------------------

import json 
js3=json.dumps(soaps_shampoo)

fd=open("soaps_shampoo.json",'w')
fd.write(js3)

fd.close()



fd=open("soaps_shampoo.json",'r')
r3=fd.read()
fd.close()
soaps_shampoo=json.loads(r3)

#=---------------------------------------------------------------------------------------------------

import json 
js4=json.dumps(dairy_products)

fd=open("dairy_products.json",'w')
fd.write(js4)

fd.close()



fd=open("dairy_products.json",'r')
r4=fd.read()
fd.close()
dairy_products=json.loads(r4)

#-----------------------------------------------------------------------------------------------

# %%
#-------------------------------------------------------------------------------
#---------------------FOR INSERTING NEW PRODUCTS--------------------------------
#-------------------------------------------------------------------------------

print("In which category you want to add the product???")
print("\n1. FROZEN FOODS AND SNACKS\n2. OILS\n3. SOAPS AND SHAMPOO\n4. DAIRY PRODUCTS")
option=int(input("enter your choice: "))
if (option==1):
  

  fd=open("frozen_food_snacks.json",'a')
  

  id=str(input("enter the product id: "))
  name=input("enter the name of product: ")
  price=int(input("enter the price of product: "))
  mfg_date=input("enter the manufacturing date of product: ")
  exp_date=input("enter the namexpire date of product: ")
  qty=int(input("enter the quantity of product: "))
  brand=input("enter the brand name of the product: ")
  frozen_food_snacks[id]={}
  frozen_food_snacks[id]['name']=name
  frozen_food_snacks[id]['price']=price
  frozen_food_snacks[id]['mfg_date']=mfg_date
  frozen_food_snacks[id]['exp_date']=exp_date
  frozen_food_snacks[id]['qty']=qty


  js9=json.dumps(frozen_food_snacks)
  fd.write(js9)
  fd.close()

elif (option==2):
  

  fd=open("oils.json",'a')
  

  id=str(input("enter the product id: "))
  name=input("enter the name of product: ")
  price=int(input("enter the price of product: "))
  mfg_date=input("enter the manufacturing date of product: ")
  exp_date=input("enter the expire date of product: ")
  qty=int(input("enter the quantity of product: "))
  brand=input("enter the brand name of the product: ")
  oils[id]={}
  oils[id]['name']=name
  oils[id]['price']=price
  oils[id]['mfg_date']=mfg_date
  oils[id]['exp_date']=exp_date
  oils[id]['qty']=qty


  js10=json.dumps(oils)
  fd.write(js10)
  fd.close()


elif (option==3):
  

  fd=open("soaps_shampoo.json",'a')
  

  id=str(input("enter the product id: "))
  name=input("enter the name of product: ")
  price=int(input("enter the price of product: "))
  mfg_date=input("enter the manufacturing date of product: ")
  exp_date=input("enter the expire date of product: ")
  qty=int(input("enter the quantity of product: "))
  brand=input("enter the brand name of the product: ")
  soaps_shampoo[id]={}
  soaps_shampoo[id]['name']=name
  soaps_shampoo[id]['price']=price
  soaps_shampoo[id]['mfg_date']=mfg_date
  soaps_shampoo[id]['exp_date']=exp_date
  soaps_shampoo[id]['qty']=qty


  js11=json.dumps(soaps_shampoo)
  fd.write(js11)
  fd.close()


elif (option==4):
  

  fd=open("dairy_products.json",'a')
  
  id=str(input("enter the product id : "))
  name=input("enter the name of product: ")
  price=int(input("enter the price of product: "))
  mfg_date=input("enter the manufacturing date of product: ")
  exp_date=input("enter the expire date of product: ")
  qty=int(input("enter the quantity of product: "))
  brand=input("enter the brand name of the product: ")
  dairy_products[id]={}
  dairy_products[id]['name']=name
  dairy_products[id]['price']=price
  dairy_products[id]['mfg_date']=mfg_date
  dairy_products[id]['exp_date']=exp_date
  dairy_products[id]['qty']=qty


  js12=json.dumps(dairy_products)
  fd.write(js12)
  fd.close()

#---------------------------------------------------------------------------------------
#---------------------------------------------------------------------------------------
#---------------------------------------------------------------------------------------

# %%
#-------------------------------------------------------------------------------
#------------------FOR UPDATION OF EXISTING ITEMS----------------------------------
#-------------------------------------------------------------------------------
lst5=list(frozen_food_snacks.items())

lst6=list(oils.items())

lst7=list(soaps_shampoo.items())

lst8=list(dairy_products.items())
print("Which category you want to update???")
print("\n1. FROZEN FOODS AND SNACKS\n2. OILS\n3. SOAPS AND SHAMPOO\n4. DAIRY PRODUCTS")
option=int(input("enter your choice: "))
if (option==1):
  print("What do you want to update???")
  print("1. price\n2. quantity")
  ch=int(input("enter your choice: "))
  for i in lst5:
      j=i[1]
      name=list(j.items())
      p_name=name[0]
      print(str(i[0]) + '          ' + p_name[1])
  if(ch==1):
    
    id_no=str(input("enter the product id from above: "))
    up_price=int(input("enter the updated price: "))
    frozen_food_snacks[id_no]['price']=up_price
  if(ch==2):
    id_no=str(input("enter the product id from above: "))
    up_qty=int(input("how many quantity you want to add: "))
    frozen_food_snacks[id_no]['qty']=up_qty+int(frozen_food_snacks[id]['qty'])
  js5=json.dumps(frozen_food_snacks)

  fd=open("frozen_food_snacks.json",'w')
  fd.write(js5)
  fd.close()

if (option==2):
  print("What do you want to update???")
  print("1. price\n2. quantity")
  ch=int(input("enter your choice: "))
  for i in lst6:
      j=i[1]
      name=list(j.items())
      p_name=name[0]
      print(str(i[0]) + '          ' + p_name[1])
  if(ch==1):
    
    id_no=str(input("enter the product id from above: "))
    up_price=int(input("enter the updated price: "))
    oils[id_no]['price']=up_price
  if(ch==2):
    id_no=str(input("enter the product id from above: "))
    up_qty=int(input("how many quantity you want to add: "))
    oils[id_no]['qty']=up_qty+int(oils[id_no]['qty'])
  js6=json.dumps(oils)

  fd=open("oils.json",'w')
  fd.write(js6)

  fd.close()
if (option==3):
  print("What do you want to update???")
  print("1. price\n2. quantity")
  ch=int(input("enter your choice: "))
  for i in lst7:
      j=i[1]
      name=list(j.items())
      p_name=name[0]
      print(str(i[0]) + '          ' + p_name[1])
  if(ch==1):
    
    id_no=str(input("enter the product id from above: "))
    up_price=int(input("enter the updated price: "))
    soaps_shampoo[id_no]['price']=up_price
  if(ch==2):
    id_no=str(input("enter the product id from above: "))
    up_qty=int(input("how many quantity you want to add: "))
    soaps_shampoo[id_no]['qty']=up_qty+int(soaps_shampoo[id_no]['qty'])
  js7=json.dumps(soaps_shampoo)

  fd=open("soaps_shampoo.json",'w')
  fd.write(js7)

  fd.close()
if (option==4):
  print("What do you want to update???")
  print("1. price\n2. quantity")
  ch=int(input("enter your choice: "))
  for i in lst8:
      j=i[1]
      name=list(j.items())
      p_name=name[0]
      print(str(i[0]) + '          ' + p_name[1])
  if(ch==1):
    id_no=str(input("enter the product id from above: "))
    up_price=int(input("enter the updated price: "))
    dairy_products[id_no]['price']=up_price
  if(ch==2):
    id_no=str(input("enter the product id from above: "))
    up_qty=int(input("how many products you want to add: "))
    dairy_products[id_no]['qty']=up_qty+int(dairy_products[id_no]['price'])
  js8=json.dumps(dairy_products)

  fd=open("dairy_products.json",'w')
  fd.write(js8)

  fd.close()

#---------------------------------------------------------------------------------

# %%
#-------------------------------------------------------------------------------------------
#-----------------------------FOR PURCHASING PURPOSE----------------------------------------
#-------------------------------------------------------------------------------------------

item_purchased=[]
total_qty=[]
price_per_purchase=[]

lst1=list(frozen_food_snacks.items())

lst2=list(oils.items())

lst3=list(soaps_shampoo.items())

lst4=list(dairy_products.items())
print("WELCOME TO JAIN GROCERY STORE\n")
print("\n1. FROZEN FOODS AND SNACKS\n2. OILS\n3. SOAPS AND SHAMPOO\n4. DAIRY PRODUCTS")

n=int(input("please enter, from how many categories you want to shop?: "))
amount=0
for k in range (1,n+1):
 
  print("PLEASE SELECT THE CATEGORY FROM BELOW\n")
  print("\n1. FROZEN FOODS AND SNACKS\n2. OILS\n3. SOAPS AND SHAMPOO\n4. DAIRY PRODUCTS")
  print("-----------------------------------\n")
  choice=int(input("enter your choice from the above list: "))
  print("id"+'             '+"product name")

  if (choice==1):
    for i in lst1:

      j=i[1]
      name=list(j.items())
      p_name=name[0]
      print(str(i[0]) + '          ' + p_name[1])
    number=int(input("how many items do you want to buy from above list: "))
    for product in range(1,number+1):
          id=str(input("enter the product id from above: "))
          quantity=int(input("enter the quantity you want: "))
          item_purchased.append(frozen_food_snacks[id]['name'])
          total_qty.append(quantity)
          print("price of your product per piece is: ",frozen_food_snacks[id]['price'])


 
          amount1=int(frozen_food_snacks[id]['price'])*quantity
          price_per_purchase.append(amount1)
          print("total amount: ",amount1)
          amount+=amount1
          frozen_food_snacks[id]['qty']=int(frozen_food_snacks[id]['qty'])-quantity
          js1=json.dumps(frozen_food_snacks)

          fd=open("frozen_food_snacks.json",'w')
          fd.write(js1)
          fd.close()

  elif (choice==2):
     for i in lst2:

        j1=i[1]
        name=list(j1.items())
        p_oname=name[0]
        print(str(i[0]) + '          ' + p_oname[1])
     print("5 Kg packing for all the available oils\n")
     number=int(input("how many items do you want to buy from above list: "))
     for product in range(1,number+1):
          id=str(input("enter the product id from above: "))
          quantity=int(input("enter the quantity you want: "))
          item_purchased.append(oils[id]['name'])
          total_qty.append(quantity)
          print("price of your product per piece is: ",oils[id]['price'])

 
          amount1=int(oils[id]['price'])*quantity
          price_per_purchase.append(amount1)
          print("total amount: ",amount1)
          amount+=amount1
          oils[id]['qty']=int(oils[id]['qty'])-quantity
          js2=json.dumps(oils)

          fd=open("oils.json",'w')
          fd.write(js2)

          fd.close()

  elif (choice==3):
      for i in lst3:

          j=i[1]
          name=list(j.items())
          p_name=name[0]
          print(str(i[0]) + '          ' + p_name[1])
      print("shampoo bottles comes in 1 litre packing and soap comes in 3 pack combo\n")
      number=int(input("how many items do you want to buy from above list: "))
      for product in range(1,number+1):
              id=str(input("enter the product id from above: "))
              quantity=int(input("enter the quantity you want: "))
              print("price of your product per piece is: ",soaps_shampoo[id]['price'])
           
 
              amount1=int(soaps_shampoo[id]['price'])*quantity
              price_per_purchase.append(amount1)
              item_purchased.append(soaps_shampoo[id]['name'])
              total_qty.append(quantity)

              print("total amount: ",amount1)
              amount+=amount1
              soaps_shampoo[id]['qty']=int(soaps_shampoo[id]['qty'])-quantity
              js3=json.dumps(soaps_shampoo)

              fd=open("soaps_shampoo.json",'w')
              fd.write(js3)

              fd.close()

  elif (choice==4):
     for i in lst4:

        j=i[1]
        name=list(j.items())
        p_name=name[0]
        print(str(i[0]) + '          ' + p_name[1])
     print("1 Kg packings for all\n")
     number=int(input("how many items do you want to buy from above list: "))
     for product in range(1,number+1):
           id=str(input("enter the product id from above: "))
           quantity=int(input("enter the quantity you want: "))
           print("price of your product per piece is: ",dairy_products[id]['price'])
           item_purchased.append(dairy_products[id]['name'])
           total_qty.append(quantity)

 
           amount1=int(dairy_products[id]['price'])*quantity
           price_per_purchase.append(amount1)
           print("total amount: ",amount1)
           amount+=amount1
           dairy_products[id]['qty']=int(dairy_products[id]['qty'])-quantity
           js4=json.dumps(dairy_products)

           fd=open("dairy_products.json",'w')
           fd.write(js4)

           fd.close()
  else:
    print("wrong choice:")
#-----------------------------------------------------------------------------------------
#----------------------------------BILL SYSTEM--------------------------------------------
#-----------------------------------------------------------------------------------------
import time
date_time=time.ctime()
print("-----------------------------------------------------------\n\n")

cust_name=input("entre the name of the customer: ")
cust_phone=int(input("enter customer's phone number: "))
cust_address=input("enter customer's address: ")
bill_no=int(input("enter the bill number: "))

print("----------------------------------------------------------")
print("----------------------------------------------------------")
print("\n\n--------------------JAIN GROCERY LIST---------------------\n")

print("NEAR 4 SQUARE COMPLEX, MAHARASHTRA MUMBAI")
print("phone no.= 8855223366")
print("email-id: delitegrocery@gmail.com")

print("-----------------------------------------------------------\n\n")

print("customer name: ",cust_name  )
print("customer's address: ",cust_address + "                     " + "invoice number: ",str(bill_no))
print("mobile number: ",cust_phone)
print("date and time: ",date_time)

print("------------------------------------------------------------")

print("items you have purchase: ",item_purchased)
print("quantity of each item you have bought: ",total_qty)
print("price you have paid per product: ",price_per_purchase)
  

print("---------------------------------------------")
print("total amount to be paid: ",amount)
print("---------------------------------------------")

#---------------------------------------------------------------------------------------------------------
#-----------------------------FILE FOR KEEPING RECORD OF CUSTOMER'S PURCHASE-------------------------------
#----------------------------------------------------------------------------------------------------------


fd=open("purchase.json",'a')
purchase={}


purchase['customer_name']=cust_name
purchase['customer_mobile_no']=cust_phone
purchase['customer_address']=cust_address
purchase['invoice_number']=bill_no
purchase['paid_amount']=amount





js13=json.dumps(purchase)


fd.write(js13)
fd.write("\n")

fd.close()
#---------------------------------------------------------------------------------------------------------------------



#---------------------------------------------------------------------------------------------------------------------
#-------------------------------------------FOR CALCULATING SALES-----------------------------------------------------
#---------------------------------------------------------------------------------------------------------------------
import json
fd=open("sales.json",'a')
sales={}

t_id= input("enter the trans_id : ")
sales['trans_id']=t_id
sales['customer_name']=cust_name
sales['invoice_no']=bill_no
sales['transaction_amount']=amount




js5=json.dumps(sales)


fd.write(js5)
fd.write("\n")

fd.close()
#-------------------------------------------------------------------------------
